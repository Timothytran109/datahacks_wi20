# %%
import pandas as pd
import math
import numpy as np
import matplotlib as plt

# %%
df = pd.read_csv("U.S._Chronic_Disease_Indicators__CDI_.csv")
df= df[df['DatavalueFootnote'] != 'No data available']
df = df[pd.notnull(df['DatavalueFootnote'])]
df = df.drop(['DataValueFootnoteSymbol'], axis = 1)
df = df.drop(['StratificationCategoryID2', 'StratificationCategoryID3', 'StratificationID2', 'StratificationID3'], axis = 1)
df = df.drop(['StratificationCategory2', 'StratificationCategory3', 'Stratification2', 'Stratification3'], axis = 1)
df = df.drop(['ResponseID'], axis = 1)
df = df.drop(['Response'] , axis = 1)
df = df.drop(['LocationID'], axis = 1)
df.sort_values('DataValue', ascending = False)
df = df.drop(['QuestionID'], axis = 1)
df
# Out:
#         YearStart  YearEnd LocationAbbr          LocationDesc  \
# 19           2012     2012           WY               Wyoming
# 20           2012     2012           WY               Wyoming
# 26           2015     2015           UT                  Utah
# 30           2015     2015           NC        North Carolina
# 31           2012     2012           MT               Montana
# 40           2012     2012           VA              Virginia
# 45           2015     2015           WV         West Virginia
# 46           2015     2015           UT                  Utah
# 49           2015     2015           WV         West Virginia
# 53           2012     2012           UT                  Utah
# 61           2012     2012           PA          Pennsylvania
# 64           2015     2015           ID                 Idaho
# 67           2015     2015           IA                  Iowa
# 68           2012     2012           PA          Pennsylvania
# ...

# %%
plt.plot()
